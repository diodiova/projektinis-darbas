# %%
import lyricsgenius
import json
import time
from datetime import datetime
import requests
import os

# %%
GENIUS_API_TOKEN = "(Čia turėtų būti API raktas)"
BASE_URL = "https://api.genius.com"

start_year = 1980
end_year = 2020

artists_in_period = ["Michael Jackson", "Bad Boys Blue", "Madonna", "Modern Talking", "Ace of Base", "Scorpions", "Metallica", "Depeche Mode", "Boney M.", "Joy (AUT)", "Aerosmith", "Elton John", "Nirvana", "2Pac", "Radiohead", "Green Day", "Snoop Dogg", "Pearl Jam", "Red Hot Chili Peppers", "2 Unlimited", "Vengaboys", "Ice MC", "MIKA", "R.E.M.", "Coolio", "The Smashing Pumpkins", "Eminem", "Coldplay", "OutKast", "Linkin Park", "50 Cent", "Cascada", "Kanye West", "U2", "Britney Spears", "Kylie Minogue", "Rihanna", "Katy Perry", "Pitbull", "Ariana Grande", "Selena Gomez", "Shakira", "Lady Gaga", "Imagine Dragons", "The Weeknd", "Kendrick Lamar", "David Guetta", "Calvin Harris"]

genius = lyricsgenius.Genius(
    GENIUS_API_TOKEN,
    skip_non_songs=True,
    excluded_terms=["(Remix)", "(Live)"],
    timeout = 15,
    retries = 3
)

def get_song_release_date(song_id):
    headers = {"Authorization": f"Bearer {GENIUS_API_TOKEN}"}
    response = requests.get(f"{BASE_URL}/songs/{song_id}", headers=headers)

    if response.status_code == 200:
        song_data = response.json()["response"]["song"]
        return song_data.get("release_date", None)
    else:
        print(f"Klaida gaunant release_date song_id {song_id}: {response.status_code}")
        return None

all_lyrics = []
total_word_count = 0

for artist_name in artists_in_period:
    print(f"Surandame dainas atlikejui: {artist_name}")
    try:
        artist = genius.search_artist(artist_name, max_songs=5, sort="popularity")
    except Exception as e:
        print(f"Klaida su atlikeju {artist_name}: {e}")
        continue

    time.sleep(2)

    if artist:
        for song in artist.songs:
            full_song = genius.search_song(song.title, artist.name)
            if not full_song or not full_song.lyrics:
                print(f"Nepavyko gauti lyrics dainai: {song.title}")
                continue
            
            release_date = get_song_release_date(full_song.id)

            if release_date:
                try:
                    release_year = datetime.strptime(release_date, "%Y-%m-%d").year
                except ValueError:
                    try:
                        release_year = datetime.strptime(release_date, "%Y").year
                    except ValueError:
                        print(f"Klaida: neteisingas release_date formatas {release_date} dainai {song.title}")
                        release_year = None
            else:
                release_year = None

            if release_year is None or (start_year <= release_year <= end_year):
                lyrics = full_song.lyrics
                word_count = len(lyrics.split())
                total_word_count += word_count
                all_lyrics.append({
                    "artist": full_song.artist,
                    "title": full_song.title,
                    "year": release_year,
                    "lyrics": lyrics,
                    "word_count": word_count
                })
                print(f"{full_song.title} ({release_year}) - {word_count} žodžių (viso: {total_word_count})")

all_lyrics.sort(key=lambda song: song["year"] if song["year"] is not None else 0)

filename = "Dainu_analize_1980_2020.json"
with open(filename, "w", encoding="utf-8") as f:
    json.dump(all_lyrics, f, ensure_ascii=False, indent=2)

print(f"Iš viso surinkta {len(all_lyrics)} dainų, {total_word_count} žodžių")
# Out:
# Surandame dainas atlikejui: Michael Jackson
# Searching for songs by Michael Jackson...
#
# Song 1: "Billie Jean"
# Song 2: "Smooth Criminal"
# Song 3: "Wanna Be Startin’ Somethin’"
# Song 4: "Thriller"
# Song 5: "They Don’t Care About Us"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Billie Jean" by Michael Jackson...
# Done.
# Billie Jean (1982) - 627 žodžių (viso: 627)
# Searching for "Smooth Criminal" by Michael Jackson...
# Done.
# Smooth Criminal (1987) - 617 žodžių (viso: 1244)
# Searching for "Wanna Be Startin’ Somethin’" by Michael Jackson...
# Done.
# Wanna Be Startin’ Somethin’ (1982) - 1023 žodžių (viso: 2267)
# Searching for "Thriller" by Michael Jackson...
# Done.
# Thriller (1982) - 546 žodžių (viso: 2813)
# Searching for "They Don’t Care About Us" by Michael Jackson...
# Done.
# They Don’t Care About Us (1995) - 636 žodžių (viso: 3449)
# Surandame dainas atlikejui: Bad Boys Blue
# Searching for songs by Bad Boys Blue...
#
# Song 1: "You’re a Woman"
# Song 2: "Pretty Young Girl"
# Song 3: "I Wanna Hear Your Heartbeat (Sunday Girl)"
# Song 4: "Lady in Black"
# Song 5: "Come Back and Stay"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "You’re a Woman" by Bad Boys Blue...
# Done.
# You’re a Woman (1985) - 172 žodžių (viso: 3621)
# Searching for "Pretty Young Girl" by Bad Boys Blue...
# Done.
# Pretty Young Girl (1985) - 259 žodžių (viso: 3880)
# Searching for "I Wanna Hear Your Heartbeat (Sunday Girl)" by Bad Boys Blue...
# Done.
# I Wanna Hear Your Heartbeat (Sunday Girl) (1986) - 340 žodžių (viso: 4220)
# Searching for "Lady in Black" by Bad Boys Blue...
# Done.
# Lady in Black (1989) - 287 žodžių (viso: 4507)
# Searching for "Come Back and Stay" by Bad Boys Blue...
# Done.
# Come Back and Stay (1987) - 270 žodžių (viso: 4777)
# Surandame dainas atlikejui: Madonna
# Searching for songs by Madonna...
#
# Song 1: "Like a Prayer"
# Song 2: "La Isla Bonita"
# Song 3: "Material Girl"
# "BREAK MY SOUL (THE QUEENS REMIX)" is not valid. Skipping.
# Song 4: "Vogue"
# Song 5: "Frozen"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Like a Prayer" by Madonna...
# Done.
# Like a Prayer (1989) - 600 žodžių (viso: 5377)
# Searching for "La Isla Bonita" by Madonna...
# Done.
# La Isla Bonita (1986) - 388 žodžių (viso: 5765)
# Searching for "Material Girl" by Madonna...
# Done.
# Material Girl (1984) - 390 žodžių (viso: 6155)
# Searching for "Vogue" by Madonna...
# Done.
# Vogue (1990) - 499 žodžių (viso: 6654)
# Searching for "Frozen" by Madonna...
# Done.
# Frozen (1998) - 265 žodžių (viso: 6919)
# Surandame dainas atlikejui: Modern Talking
# Searching for songs by Modern Talking...
#
# Song 1: "Cheri Cheri Lady"
# Song 2: "Brother Louie"
# Song 3: "Sexy Sexy Lover"
# Song 4: "You’re My Heart, You’re My Soul"
# Song 5: "Geronimo’s Cadillac"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Cheri Cheri Lady" by Modern Talking...
# Done.
# Cheri Cheri Lady (1985) - 316 žodžių (viso: 7235)
# Searching for "Brother Louie" by Modern Talking...
# Done.
# Brother Louie (1986) - 330 žodžių (viso: 7565)
# Searching for "Sexy Sexy Lover" by Modern Talking...
# Done.
# Sexy Sexy Lover (1999) - 337 žodžių (viso: 7902)
# Searching for "You’re My Heart, You’re My Soul" by Modern Talking...
# Done.
# You’re My Heart, You’re My Soul (1984) - 314 žodžių (viso: 8216)
# Searching for "Geronimo’s Cadillac" by Modern Talking...
# Done.
# Geronimo’s Cadillac (1986) - 260 žodžių (viso: 8476)
# Surandame dainas atlikejui: Ace of Base
# Searching for songs by Ace of Base...
#
# Song 1: "The Sign"
# Song 2: "All That She Wants"
# Song 3: "Happy Nation"
# Song 4: "Beautiful Life"
# Song 5: "Don’t Turn Around"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "The Sign" by Ace of Base...
# Done.
# The Sign (1993) - 340 žodžių (viso: 8816)
# Searching for "All That She Wants" by Ace of Base...
# Done.
# All That She Wants (1992) - 318 žodžių (viso: 9134)
# Searching for "Happy Nation" by Ace of Base...
# Done.
# Happy Nation (1992) - 247 žodžių (viso: 9381)
# Searching for "Beautiful Life" by Ace of Base...
# Done.
# Beautiful Life (1995) - 319 žodžių (viso: 9700)
# Searching for "Don’t Turn Around" by Ace of Base...
# Done.
# Don’t Turn Around (1993) - 415 žodžių (viso: 10115)
# Surandame dainas atlikejui: Scorpions
# Searching for songs by Scorpions...
#
# Song 1: "Wind of Change"
# Song 2: "Still Loving You"
# Song 3: "Rock You Like a Hurricane"
# Song 4: "Send Me an Angel"
# Song 5: "Always Somewhere"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Wind of Change" by Scorpions...
# Done.
# Wind of Change (1990) - 352 žodžių (viso: 10467)
# Searching for "Still Loving You" by Scorpions...
# Done.
# Still Loving You (1984) - 348 žodžių (viso: 10815)
# Searching for "Rock You Like a Hurricane" by Scorpions...
# Done.
# Rock You Like a Hurricane (None) - 367 žodžių (viso: 11182)
# Searching for "Send Me an Angel" by Scorpions...
# Done.
# Send Me an Angel (1991) - 291 žodžių (viso: 11473)
# Searching for "Always Somewhere" by Scorpions...
# Done.
# Surandame dainas atlikejui: Metallica
# Searching for songs by Metallica...
#
# Song 1: "One"
# Song 2: "Nothing Else Matters"
# Song 3: "Enter Sandman"
# Song 4: "Master of Puppets"
# Song 5: "The Unforgiven"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "One" by Metallica...
# Done.
# One (1988) - 315 žodžių (viso: 11788)
# Searching for "Nothing Else Matters" by Metallica...
# Done.
# Nothing Else Matters (1991) - 278 žodžių (viso: 12066)
# Searching for "Enter Sandman" by Metallica...
# Done.
# Enter Sandman (1991) - 292 žodžių (viso: 12358)
# Searching for "Master of Puppets" by Metallica...
# Done.
# Master of Puppets (1986) - 396 žodžių (viso: 12754)
# Searching for "The Unforgiven" by Metallica...
# Done.
# The Unforgiven (1991) - 355 žodžių (viso: 13109)
# Surandame dainas atlikejui: Depeche Mode
# Searching for songs by Depeche Mode...
#
# Song 1: "Enjoy the Silence"
# Song 2: "Personal Jesus"
# Song 3: "Everything Counts"
# Song 4: "Never Let Me Down Again"
# Song 5: "Strangelove"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Enjoy the Silence" by Depeche Mode...
# Done.
# Enjoy the Silence (1990) - 199 žodžių (viso: 13308)
# Searching for "Personal Jesus" by Depeche Mode...
# Done.
# Personal Jesus (1990) - 234 žodžių (viso: 13542)
# Searching for "Everything Counts" by Depeche Mode...
# Done.
# Everything Counts (1983) - 277 žodžių (viso: 13819)
# Searching for "Never Let Me Down Again" by Depeche Mode...
# Done.
# Never Let Me Down Again (1987) - 322 žodžių (viso: 14141)
# Searching for "Strangelove" by Depeche Mode...
# Done.
# Strangelove (1987) - 309 žodžių (viso: 14450)
# Surandame dainas atlikejui: Boney M.
# Searching for songs by Boney M....
#
# Changing artist name to 'Boney M.'
# Song 1: "Rasputin"
# Song 2: "Rivers of Babylon"
# Song 3: "Mary’s Boy Child / Oh My Lord"
# Song 4: "Daddy Cool"
# Song 5: "Sunny"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Rasputin" by Boney M....
# Done.
# Searching for "Rivers of Babylon" by Boney M....
# Done.
# Searching for "Mary’s Boy Child / Oh My Lord" by Boney M....
# Done.
# Searching for "Daddy Cool" by Boney M....
# Done.
# Searching for "Sunny" by Boney M....
# Done.
# Surandame dainas atlikejui: Joy (AUT)
# Searching for songs by Joy (AUT)...
#
# Song 1: "Touch by Touch"
# Song 2: "Valerie"
# Song 3: "Hello"
# Song 4: "I’m in Love"
# Song 5: "Japanese Girls"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Touch by Touch" by Joy (AUT)...
# Done.
# Touch by Touch (1985) - 256 žodžių (viso: 14706)
# Searching for "Valerie" by Joy (AUT)...
# Done.
# Valerie (None) - 368 žodžių (viso: 15074)
# Searching for "Hello" by Joy (AUT)...
# Done.
# Hello (None) - 204 žodžių (viso: 15278)
# Searching for "I’m in Love" by Joy (AUT)...
# Done.
# I’m in Love (None) - 394 žodžių (viso: 15672)
# Searching for "Japanese Girls" by Joy (AUT)...
# Done.
# Japanese Girls (None) - 120 žodžių (viso: 15792)
# Surandame dainas atlikejui: Aerosmith
# Searching for songs by Aerosmith...
#
# Song 1: "Dream On"
# Song 2: "I Don’t Want to Miss a Thing"
# Song 3: "Cryin’"
# Song 4: "Walk This Way"
# Song 5: "Love in an Elevator"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Dream On" by Aerosmith...
# Done.
# Searching for "I Don’t Want to Miss a Thing" by Aerosmith...
# Done.
# I Don’t Want to Miss a Thing (1998) - 424 žodžių (viso: 16216)
# Searching for "Cryin’" by Aerosmith...
# Done.
# Cryin’ (1993) - 432 žodžių (viso: 16648)
# Searching for "Walk This Way" by Aerosmith...
# Done.
# Searching for "Love in an Elevator" by Aerosmith...
# Done.
# Love in an Elevator (1989) - 546 žodžių (viso: 17194)
# Surandame dainas atlikejui: Elton John
# Searching for songs by Elton John...
#
# Song 1: "Your Song"
# Song 2: "I’m Still Standing"
# Song 3: "Bennie and the Jets"
# Song 4: "Tiny Dancer"
# Song 5: "Don’t Let the Sun Go Down on Me"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Your Song" by Elton John...
# Done.
# Searching for "I’m Still Standing" by Elton John...
# Done.
# I’m Still Standing (1983) - 355 žodžių (viso: 17549)
# Searching for "Bennie and the Jets" by Elton John...
# Done.
# Searching for "Tiny Dancer" by Elton John...
# Done.
# Searching for "Don’t Let the Sun Go Down on Me" by Elton John...
# Done.
# Surandame dainas atlikejui: Nirvana
# Searching for songs by Nirvana...
#
# Song 1: "Smells Like Teen Spirit"
# Song 2: "Come as You Are"
# Song 3: "Heart-Shaped Box"
# Song 4: "Lithium"
# Song 5: "Drain You"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Smells Like Teen Spirit" by Nirvana...
# Done.
# Smells Like Teen Spirit (1991) - 310 žodžių (viso: 17859)
# Searching for "Come as You Are" by Nirvana...
# Done.
# Come as You Are (1991) - 190 žodžių (viso: 18049)
# Searching for "Heart-Shaped Box" by Nirvana...
# Done.
# Heart-Shaped Box (1993) - 295 žodžių (viso: 18344)
# Searching for "Lithium" by Nirvana...
# Done.
# Lithium (1991) - 347 žodžių (viso: 18691)
# Searching for "Drain You" by Nirvana...
# Done.
# Drain You (1991) - 239 žodžių (viso: 18930)
# Surandame dainas atlikejui: 2Pac
# Searching for songs by 2Pac...
#
# Song 1: "Hit ’Em Up"
# Song 2: "Changes"
# Song 3: "Keep Ya Head Up"
# Song 4: "California Love"
# Song 5: "Dear Mama"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Hit ’Em Up" by 2Pac...
# Done.
# Hit ’Em Up (1996) - 1250 žodžių (viso: 20180)
# Searching for "Changes" by 2Pac...
# Done.
# Changes (1998) - 951 žodžių (viso: 21131)
# Searching for "Keep Ya Head Up" by 2Pac...
# Done.
# Keep Ya Head Up (1993) - 933 žodžių (viso: 22064)
# Searching for "California Love" by 2Pac...
# Done.
# California Love (1996) - 654 žodžių (viso: 22718)
# Searching for "Dear Mama" by 2Pac...
# Done.
# Dear Mama (1995) - 778 žodžių (viso: 23496)
# Surandame dainas atlikejui: Radiohead
# Searching for songs by Radiohead...
#
# Song 1: "Creep"
# Song 2: "Karma Police"
# Song 3: "No Surprises"
# Song 4: "Exit Music (For A Film)"
# Song 5: "Paranoid Android"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Creep" by Radiohead...
# Done.
# Creep (1992) - 218 žodžių (viso: 23714)
# Searching for "Karma Police" by Radiohead...
# Done.
# Karma Police (1997) - 184 žodžių (viso: 23898)
# Searching for "No Surprises" by Radiohead...
# Done.
# No Surprises (1997) - 176 žodžių (viso: 24074)
# Searching for "Exit Music (For A Film)" by Radiohead...
# Done.
# Exit Music (For A Film) (1997) - 163 žodžių (viso: 24237)
# Searching for "Paranoid Android" by Radiohead...
# Done.
# Paranoid Android (1997) - 263 žodžių (viso: 24500)
# Surandame dainas atlikejui: Green Day
# Searching for songs by Green Day...
#
# Song 1: "Boulevard of Broken Dreams"
# Song 2: "American Idiot"
# Song 3: "Holiday"
# Song 4: "Basket Case"
# Song 5: "Good Riddance (Time of Your Life)"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Boulevard of Broken Dreams" by Green Day...
# Done.
# Boulevard of Broken Dreams (2004) - 317 žodžių (viso: 24817)
# Searching for "American Idiot" by Green Day...
# Done.
# American Idiot (2004) - 232 žodžių (viso: 25049)
# Searching for "Holiday" by Green Day...
# Done.
# Holiday (2004) - 306 žodžių (viso: 25355)
# Searching for "Basket Case" by Green Day...
# Done.
# Basket Case (1994) - 216 žodžių (viso: 25571)
# Searching for "Good Riddance (Time of Your Life)" by Green Day...
# Done.
# Good Riddance (Time of Your Life) (1997) - 207 žodžių (viso: 25778)
# Surandame dainas atlikejui: Snoop Dogg
# Searching for songs by Snoop Dogg...
#
# Song 1: "Gin and Juice"
# Song 2: "Young, Wild & Free"
# "My Nigga (Remix)" is not valid. Skipping.
# Song 3: "Drop It Like It’s Hot"
# Song 4: "Ain’t No Fun (If the Homies Can’t Have None)"
# Song 5: "Who Am I (What’s My Name)?"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Gin and Juice" by Snoop Dogg...
# Done.
# Gin and Juice (1993) - 716 žodžių (viso: 26494)
# Searching for "Young, Wild & Free" by Snoop Dogg...
# Done.
# Young, Wild & Free (2011) - 593 žodžių (viso: 27087)
# Searching for "Drop It Like It’s Hot" by Snoop Dogg...
# Done.
# Drop It Like It’s Hot (2004) - 861 žodžių (viso: 27948)
# Searching for "Ain’t No Fun (If the Homies Can’t Have None)" by Snoop Dogg...
# Done.
# Ain’t No Fun (If the Homies Can’t Have None) (1993) - 671 žodžių (viso: 28619)
# Searching for "Who Am I (What’s My Name)?" by Snoop Dogg...
# Done.
# Who Am I (What’s My Name)? (1993) - 557 žodžių (viso: 29176)
# Surandame dainas atlikejui: Pearl Jam
# Searching for songs by Pearl Jam...
#
# "Alive" is not valid. Skipping.
# Song 1: "Black"
# Song 2: "Even Flow"
# Song 3: "Jeremy"
# Song 4: "Yellow Ledbetter"
# Song 5: "Better Man"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Black" by Pearl Jam...
# Done.
# Black (1991) - 327 žodžių (viso: 29503)
# Searching for "Even Flow" by Pearl Jam...
# Done.
# Even Flow (1992) - 291 žodžių (viso: 29794)
# Searching for "Jeremy" by Pearl Jam...
# Done.
# Jeremy (1991) - 306 žodžių (viso: 30100)
# Searching for "Yellow Ledbetter" by Pearl Jam...
# Done.
# Yellow Ledbetter (None) - 256 žodžių (viso: 30356)
# Searching for "Better Man" by Pearl Jam...
# Done.
# Better Man (1994) - 293 žodžių (viso: 30649)
# Surandame dainas atlikejui: Red Hot Chili Peppers
# Searching for songs by Red Hot Chili Peppers...
#
# Song 1: "Californication"
# Song 2: "Under the Bridge"
# Song 3: "Can’t Stop"
# Song 4: "Otherside"
# Song 5: "Scar Tissue"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Californication" by Red Hot Chili Peppers...
# Done.
# Californication (1999) - 334 žodžių (viso: 30983)
# Searching for "Under the Bridge" by Red Hot Chili Peppers...
# Done.
# Under the Bridge (1991) - 328 žodžių (viso: 31311)
# Searching for "Can’t Stop" by Red Hot Chili Peppers...
# Done.
# Can’t Stop (2003) - 616 žodžių (viso: 31927)
# Searching for "Otherside" by Red Hot Chili Peppers...
# Done.
# Otherside (1999) - 361 žodžių (viso: 32288)
# Searching for "Scar Tissue" by Red Hot Chili Peppers...
# Done.
# Scar Tissue (1999) - 340 žodžių (viso: 32628)
# Surandame dainas atlikejui: 2 Unlimited
# Searching for songs by 2 Unlimited...
#
# Song 1: "No Limit"
# Song 2: "Get Ready For This"
# Song 3: "Twilight Zone"
# Song 4: "Tribal Dance"
# Song 5: "Jump for Joy"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "No Limit" by 2 Unlimited...
# Done.
# No Limit (1993) - 354 žodžių (viso: 32982)
# Searching for "Get Ready For This" by 2 Unlimited...
# Done.
# Get Ready For This (1991) - 364 žodžių (viso: 33346)
# Searching for "Twilight Zone" by 2 Unlimited...
# Done.
# Twilight Zone (1992) - 291 žodžių (viso: 33637)
# Searching for "Tribal Dance" by 2 Unlimited...
# Done.
# Tribal Dance (1993) - 324 žodžių (viso: 33961)
# Searching for "Jump for Joy" by 2 Unlimited...
# Done.
# Jump for Joy (1996) - 389 žodžių (viso: 34350)
# Surandame dainas atlikejui: Vengaboys
# Searching for songs by Vengaboys...
#
# Song 1: "Boom, Boom, Boom, Boom!!"
# Song 2: "We like to Party!"
# Song 3: "We Like to Party (More Airplay)"
# Song 4: "Shalala Lala"
# Song 5: "We’re Going to Ibiza!"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Boom, Boom, Boom, Boom!!" by Vengaboys...
# Done.
# Boom, Boom, Boom, Boom!! (1999) - 348 žodžių (viso: 34698)
# Searching for "We like to Party!" by Vengaboys...
# Done.
# We like to Party! (1999) - 370 žodžių (viso: 35068)
# Searching for "We Like to Party (More Airplay)" by Vengaboys...
# Done.
# We Like to Party (More Airplay) (1999) - 391 žodžių (viso: 35459)
# Searching for "Shalala Lala" by Vengaboys...
# Done.
# Shalala Lala (2000) - 234 žodžių (viso: 35693)
# Searching for "We’re Going to Ibiza!" by Vengaboys...
# Done.
# We’re Going to Ibiza! (1999) - 330 žodžių (viso: 36023)
# Surandame dainas atlikejui: Ice MC
# Searching for songs by Ice MC...
#
# Song 1: "Think About The Way"
# Song 2: "It’s A Rainy Day"
# Song 3: "Easy"
# Song 4: "Scream"
# Song 5: "Cinema"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Think About The Way" by Ice MC...
# Done.
# Think About The Way (None) - 444 žodžių (viso: 36467)
# Searching for "It’s A Rainy Day" by Ice MC...
# Done.
# It’s A Rainy Day (None) - 357 žodžių (viso: 36824)
# Searching for "Easy" by Ice MC...
# Done.
# Easy (1990) - 505 žodžių (viso: 37329)
# Searching for "Scream" by Ice MC...
# Done.
# Scream (1990) - 338 žodžių (viso: 37667)
# Searching for "Cinema" by Ice MC...
# Done.
# Cinema (1990) - 439 žodžių (viso: 38106)
# Surandame dainas atlikejui: MIKA
# Searching for songs by MIKA...
#
# Song 1: "Grace Kelly"
# Song 2: "Lollipop"
# Song 3: "Popular Song"
# Song 4: "Relax, Take It Easy"
# Song 5: "Love Today"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Grace Kelly" by MIKA...
# Done.
# Grace Kelly (2007) - 483 žodžių (viso: 38589)
# Searching for "Lollipop" by MIKA...
# Done.
# Lollipop (2007) - 393 žodžių (viso: 38982)
# Searching for "Popular Song" by MIKA...
# Done.
# Popular Song (2012) - 622 žodžių (viso: 39604)
# Searching for "Relax, Take It Easy" by MIKA...
# Done.
# Relax, Take It Easy (2007) - 324 žodžių (viso: 39928)
# Searching for "Love Today" by MIKA...
# Done.
# Love Today (2007) - 223 žodžių (viso: 40151)
# Surandame dainas atlikejui: R.E.M.
# Searching for songs by R.E.M....
#
# Song 1: "Losing My Religion"
# Song 2: "It’s the End of the World as We Know It (And I Feel Fine)"
# Song 3: "Man on the Moon"
# Song 4: "Everybody Hurts"
# Song 5: "Orange Crush"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Losing My Religion" by R.E.M....
# Done.
# Losing My Religion (1991) - 333 žodžių (viso: 40484)
# Searching for "It’s the End of the World as We Know It (And I Feel Fine)" by R.E.M....
# Done.
# It’s the End of the World as We Know It (And I Feel Fine) (1987) - 673 žodžių (viso: 41157)
# Searching for "Man on the Moon" by R.E.M....
# Done.
# Man on the Moon (1992) - 451 žodžių (viso: 41608)
# Searching for "Everybody Hurts" by R.E.M....
# Done.
# Everybody Hurts (1993) - 227 žodžių (viso: 41835)
# Searching for "Orange Crush" by R.E.M....
# Done.
# Orange Crush (1988) - 365 žodžių (viso: 42200)
# Surandame dainas atlikejui: Coolio
# Searching for songs by Coolio...
#
# Song 1: "Gangsta’s Paradise"
# Song 2: "Aw, Here It Goes (Kenan and Kel Show Theme Song)"
# Song 3: "C U When U Get There"
# Song 4: "1, 2, 3, 4 (Sumpin’ New)"
# Song 5: "Fantastic Voyage"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Gangsta’s Paradise" by Coolio...
# Done.
# Gangsta’s Paradise (1995) - 555 žodžių (viso: 42755)
# Searching for "Aw, Here It Goes (Kenan and Kel Show Theme Song)" by Coolio...
# Done.
# Aw, Here It Goes (Kenan and Kel Show Theme Song) (1996) - 181 žodžių (viso: 42936)
# Searching for "C U When U Get There" by Coolio...
# Done.
# C U When U Get There (1997) - 800 žodžių (viso: 43736)
# Searching for "1, 2, 3, 4 (Sumpin’ New)" by Coolio...
# Done.
# 1, 2, 3, 4 (Sumpin’ New) (1996) - 715 žodžių (viso: 44451)
# Searching for "Fantastic Voyage" by Coolio...
# Done.
# Fantastic Voyage (1994) - 697 žodžių (viso: 45148)
# Surandame dainas atlikejui: The Smashing Pumpkins
# Searching for songs by The Smashing Pumpkins...
#
# Song 1: "Bullet with Butterfly Wings"
# Song 2: "1979"
# Song 3: "Disarm"
# Song 4: "Mayonaise"
# Song 5: "Today"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Bullet with Butterfly Wings" by The Smashing Pumpkins...
# Done.
# Bullet with Butterfly Wings (1995) - 426 žodžių (viso: 45574)
# Searching for "1979" by The Smashing Pumpkins...
# Done.
# 1979 (1995) - 274 žodžių (viso: 45848)
# Searching for "Disarm" by The Smashing Pumpkins...
# Done.
# Disarm (1994) - 244 žodžių (viso: 46092)
# Searching for "Mayonaise" by The Smashing Pumpkins...
# Done.
# Mayonaise (1993) - 270 žodžių (viso: 46362)
# Searching for "Today" by The Smashing Pumpkins...
# Done.
# Today (1993) - 196 žodžių (viso: 46558)
# Surandame dainas atlikejui: Eminem
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Lose Yourself"
# Song 3: "Without Me"
# Song 4: "Mockingbird"
# Song 5: "The Real Slim Shady"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Rap God" by Eminem...
# Done.
# Rap God (2013) - 1589 žodžių (viso: 48147)
# Searching for "Lose Yourself" by Eminem...
# Done.
# Lose Yourself (2002) - 845 žodžių (viso: 48992)
# Searching for "Without Me" by Eminem...
# Done.
# Without Me (2002) - 828 žodžių (viso: 49820)
# Searching for "Mockingbird" by Eminem...
# Done.
# Mockingbird (2004) - 944 žodžių (viso: 50764)
# Searching for "The Real Slim Shady" by Eminem...
# Done.
# The Real Slim Shady (2000) - 1064 žodžių (viso: 51828)
# Surandame dainas atlikejui: Coldplay
# Searching for songs by Coldplay...
#
# Song 1: "Viva La Vida"
# Song 2: "The Scientist"
# Song 3: "Yellow"
# Song 4: "Fix You"
# Song 5: "Hymn for the Weekend"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Viva La Vida" by Coldplay...
# Done.
# Viva La Vida (2008) - 408 žodžių (viso: 52236)
# Searching for "The Scientist" by Coldplay...
# Done.
# The Scientist (2002) - 236 žodžių (viso: 52472)
# Searching for "Yellow" by Coldplay...
# Done.
# Yellow (2000) - 280 žodžių (viso: 52752)
# Searching for "Fix You" by Coldplay...
# Done.
# Fix You (2005) - 260 žodžių (viso: 53012)
# Searching for "Hymn for the Weekend" by Coldplay...
# Done.
# Hymn for the Weekend (2016) - 472 žodžių (viso: 53484)
# Surandame dainas atlikejui: OutKast
# Searching for songs by OutKast...
#
# Song 1: "Hey Ya!"
# Song 2: "Ms. Jackson"
# Song 3: "Roses"
# Song 4: "Aquemini"
# Song 5: "B.O.B. (Bombs Over Baghdad)"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Hey Ya!" by OutKast...
# Done.
# Hey Ya! (2003) - 534 žodžių (viso: 54018)
# Searching for "Ms. Jackson" by OutKast...
# Done.
# Ms. Jackson (2000) - 783 žodžių (viso: 54801)
# Searching for "Roses" by OutKast...
# Done.
# Roses (2003) - 829 žodžių (viso: 55630)
# Searching for "Aquemini" by OutKast...
# Done.
# Aquemini (1998) - 849 žodžių (viso: 56479)
# Searching for "B.O.B. (Bombs Over Baghdad)" by OutKast...
# Done.
# B.O.B. (Bombs Over Baghdad) (2000) - 885 žodžių (viso: 57364)
# Surandame dainas atlikejui: Linkin Park
# Searching for songs by Linkin Park...
#
# Song 1: "In the End"
# Song 2: "Numb"
# Song 3: "One More Light"
# Song 4: "Heavy"
# Song 5: "The Emptiness Machine"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "In the End" by Linkin Park...
# Done.
# In the End (2000) - 465 žodžių (viso: 57829)
# Searching for "Numb" by Linkin Park...
# Done.
# Numb (2003) - 366 žodžių (viso: 58195)
# Searching for "One More Light" by Linkin Park...
# Done.
# One More Light (2017) - 273 žodžių (viso: 58468)
# Searching for "Heavy" by Linkin Park...
# Done.
# Heavy (2017) - 364 žodžių (viso: 58832)
# Searching for "The Emptiness Machine" by Linkin Park...
# Done.
# Surandame dainas atlikejui: 50 Cent
# Searching for songs by 50 Cent...
#
# Song 1: "Many Men (Wish Death)"
# Song 2: "In da Club"
# Song 3: "21 Questions"
# Song 4: "P.I.M.P."
# Song 5: "Patiently Waiting"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Many Men (Wish Death)" by 50 Cent...
# Done.
# Many Men (Wish Death) (2003) - 755 žodžių (viso: 59587)
# Searching for "In da Club" by 50 Cent...
# Done.
# In da Club (2003) - 743 žodžių (viso: 60330)
# Searching for "21 Questions" by 50 Cent...
# Done.
# 21 Questions (2003) - 698 žodžių (viso: 61028)
# Searching for "P.I.M.P." by 50 Cent...
# Done.
# P.I.M.P. (2003) - 862 žodžių (viso: 61890)
# Searching for "Patiently Waiting" by 50 Cent...
# Done.
# Patiently Waiting (2003) - 1036 žodžių (viso: 62926)
# Surandame dainas atlikejui: Cascada
# Searching for songs by Cascada...
#
# Song 1: "Everytime We Touch"
# Song 2: "Evacuate the Dancefloor"
# Song 3: "Bad Boy"
# Song 4: "What Hurts the Most"
# Song 5: "Miracle"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Everytime We Touch" by Cascada...
# Done.
# Everytime We Touch (2005) - 305 žodžių (viso: 63231)
# Searching for "Evacuate the Dancefloor" by Cascada...
# Done.
# Evacuate the Dancefloor (2009) - 585 žodžių (viso: 63816)
# Searching for "Bad Boy" by Cascada...
# Done.
# Bad Boy (2004) - 221 žodžių (viso: 64037)
# Searching for "What Hurts the Most" by Cascada...
# Done.
# What Hurts the Most (2007) - 405 žodžių (viso: 64442)
# Searching for "Miracle" by Cascada...
# Done.
# Miracle (2004) - 346 žodžių (viso: 64788)
# Surandame dainas atlikejui: Kanye West
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# Song 2: "Monster"
# Song 3: "Father Stretch My Hands Pt. 1"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Mercy" by Kanye West...
# Done.
# Mercy (2012) - 1131 žodžių (viso: 65919)
# Searching for "Monster" by Kanye West...
# Done.
# Monster (2010) - 1103 žodžių (viso: 67022)
# Searching for "Father Stretch My Hands Pt. 1" by Kanye West...
# Done.
# Father Stretch My Hands Pt. 1 (2016) - 456 žodžių (viso: 67478)
# Searching for "Ultralight Beam" by Kanye West...
# Done.
# Ultralight Beam (2016) - 806 žodžių (viso: 68284)
# Searching for "Bound 2" by Kanye West...
# Done.
# Bound 2 (2013) - 518 žodžių (viso: 68802)
# Surandame dainas atlikejui: U2
# Searching for songs by U2...
#
# Song 1: "With Or Without You"
# Song 2: "One"
# Song 3: "I Still Haven’t Found What I’m Looking For"
# Song 4: "Sunday Bloody Sunday"
# Song 5: "Pride (In the Name of Love)"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "With Or Without You" by U2...
# Done.
# With Or Without You (1987) - 247 žodžių (viso: 69049)
# Searching for "One" by U2...
# Done.
# One (1991) - 318 žodžių (viso: 69367)
# Searching for "I Still Haven’t Found What I’m Looking For" by U2...
# Done.
# I Still Haven’t Found What I’m Looking For (1987) - 259 žodžių (viso: 69626)
# Searching for "Sunday Bloody Sunday" by U2...
# Done.
# Sunday Bloody Sunday (1983) - 321 žodžių (viso: 69947)
# Searching for "Pride (In the Name of Love)" by U2...
# Done.
# Pride (In the Name of Love) (1984) - 274 žodžių (viso: 70221)
# Surandame dainas atlikejui: Britney Spears
# Searching for songs by Britney Spears...
#
# Song 1: "...Baby One More Time"
# Song 2: "Toxic"
# Song 3: "Work Bitch"
# Song 4: "Oops!...I Did It Again"
# Song 5: "If U Seek Amy"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "...Baby One More Time" by Britney Spears...
# Done.
# ...Baby One More Time (1998) - 373 žodžių (viso: 70594)
# Searching for "Toxic" by Britney Spears...
# Done.
# Toxic (2003) - 328 žodžių (viso: 70922)
# Searching for "Work Bitch" by Britney Spears...
# Done.
# Work Bitch (2013) - 486 žodžių (viso: 71408)
# Searching for "Oops!...I Did It Again" by Britney Spears...
# Done.
# Oops!...I Did It Again (2000) - 418 žodžių (viso: 71826)
# Searching for "If U Seek Amy" by Britney Spears...
# Done.
# If U Seek Amy (2009) - 654 žodžių (viso: 72480)
# Surandame dainas atlikejui: Kylie Minogue
# Searching for songs by Kylie Minogue...
#
# Song 1: "Can’t Get You Out of My Head"
# Song 2: "Chiggy Wiggy"
# Song 3: "Spinning Around"
# Song 4: "Padam Padam"
# Song 5: "Love at First Sight"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Can’t Get You Out of My Head" by Kylie Minogue...
# Done.
# Can’t Get You Out of My Head (2001) - 300 žodžių (viso: 72780)
# Searching for "Chiggy Wiggy" by Kylie Minogue...
# Done.
# Chiggy Wiggy (2009) - 633 žodžių (viso: 73413)
# Searching for "Spinning Around" by Kylie Minogue...
# Done.
# Spinning Around (2000) - 417 žodžių (viso: 73830)
# Searching for "Padam Padam" by Kylie Minogue...
# Done.
# Searching for "Love at First Sight" by Kylie Minogue...
# Done.
# Love at First Sight (2001) - 313 žodžių (viso: 74143)
# Surandame dainas atlikejui: Rihanna
# Searching for songs by Rihanna...
#
# Song 1: "Work"
# Song 2: "Love on the Brain"
# Song 3: "Needed Me"
# Song 4: "Stay"
# Song 5: "FourFiveSeconds"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Work" by Rihanna...
# Done.
# Work (2016) - 656 žodžių (viso: 74799)
# Searching for "Love on the Brain" by Rihanna...
# Done.
# Love on the Brain (2016) - 405 žodžių (viso: 75204)
# Searching for "Needed Me" by Rihanna...
# Done.
# Needed Me (2016) - 344 žodžių (viso: 75548)
# Searching for "Stay" by Rihanna...
# Done.
# Stay (2012) - 319 žodžių (viso: 75867)
# Searching for "FourFiveSeconds" by Rihanna...
# Done.
# FourFiveSeconds (2015) - 364 žodžių (viso: 76231)
# Surandame dainas atlikejui: Katy Perry
# Searching for songs by Katy Perry...
#
# Song 1: "Swish Swish"
# Song 2: "Dark Horse"
# Song 3: "California Gurls"
# Song 4: "Chained To The Rhythm"
# Song 5: "The One That Got Away"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Swish Swish" by Katy Perry...
# Done.
# Swish Swish (2017) - 575 žodžių (viso: 76806)
# Searching for "Dark Horse" by Katy Perry...
# Done.
# Dark Horse (2013) - 540 žodžių (viso: 77346)
# Searching for "California Gurls" by Katy Perry...
# Done.
# California Gurls (2010) - 514 žodžių (viso: 77860)
# Searching for "Chained To The Rhythm" by Katy Perry...
# Done.
# Chained To The Rhythm (2017) - 567 žodžių (viso: 78427)
# Searching for "The One That Got Away" by Katy Perry...
# Done.
# The One That Got Away (2010) - 380 žodžių (viso: 78807)
# Surandame dainas atlikejui: Pitbull
# Searching for songs by Pitbull...
#
# Song 1: "Feel This Moment"
# Song 2: "Timber"
# Song 3: "Give Me Everything"
# Song 4: "Hotel Room Service"
# "Time of Our Lives" is not valid. Skipping.
# Song 5: "International Love"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Feel This Moment" by Pitbull...
# Done.
# Feel This Moment (2013) - 500 žodžių (viso: 79307)
# Searching for "Timber" by Pitbull...
# Done.
# Timber (2013) - 527 žodžių (viso: 79834)
# Searching for "Give Me Everything" by Pitbull...
# Done.
# Give Me Everything (2011) - 726 žodžių (viso: 80560)
# Searching for "Hotel Room Service" by Pitbull...
# Done.
# Hotel Room Service (2009) - 591 žodžių (viso: 81151)
# Searching for "International Love" by Pitbull...
# Done.
# International Love (2011) - 633 žodžių (viso: 81784)
# Surandame dainas atlikejui: Ariana Grande
# Searching for songs by Ariana Grande...
#
# Song 1: "thank u, next"
# Song 2: "7 rings"
# Song 3: "God is a woman"
# Song 4: "Side To Side"
# Song 5: "no tears left to cry"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "thank u, next" by Ariana Grande...
# Done.
# thank u, next (2018) - 512 žodžių (viso: 82296)
# Searching for "7 rings" by Ariana Grande...
# Done.
# 7 rings (2019) - 536 žodžių (viso: 82832)
# Searching for "God is a woman" by Ariana Grande...
# Done.
# God is a woman (2018) - 498 žodžių (viso: 83330)
# Searching for "Side To Side" by Ariana Grande...
# Done.
# Side To Side (2016) - 612 žodžių (viso: 83942)
# Searching for "no tears left to cry" by Ariana Grande...
# Done.
# no tears left to cry (2018) - 570 žodžių (viso: 84512)
# Surandame dainas atlikejui: Selena Gomez
# Searching for songs by Selena Gomez...
#
# Song 1: "Lose You To Love Me"
# Song 2: "Wolves"
# Song 3: "Back To You"
# Song 4: "Fetish"
# Song 5: "Bad Liar"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Lose You To Love Me" by Selena Gomez...
# Done.
# Lose You To Love Me (2019) - 409 žodžių (viso: 84921)
# Searching for "Wolves" by Selena Gomez...
# Done.
# Wolves (2017) - 434 žodžių (viso: 85355)
# Searching for "Back To You" by Selena Gomez...
# Done.
# Back To You (2018) - 554 žodžių (viso: 85909)
# Searching for "Fetish" by Selena Gomez...
# Done.
# Fetish (2017) - 477 žodžių (viso: 86386)
# Searching for "Bad Liar" by Selena Gomez...
# Done.
# Bad Liar (2017) - 532 žodžių (viso: 86918)
# Surandame dainas atlikejui: Shakira
# Searching for songs by Shakira...
#
# Song 1: "Waka Waka (This Time for Africa)"
# Song 2: "Hips Don’t Lie"
# Song 3: "Whenever, Wherever"
# Song 4: "She Wolf"
# Song 5: "Chantaje"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Waka Waka (This Time for Africa)" by Shakira...
# Done.
# Waka Waka (This Time for Africa) (2010) - 348 žodžių (viso: 87266)
# Searching for "Hips Don’t Lie" by Shakira...
# Done.
# Hips Don’t Lie (2006) - 747 žodžių (viso: 88013)
# Searching for "Whenever, Wherever" by Shakira...
# Done.
# Whenever, Wherever (2001) - 361 žodžių (viso: 88374)
# Searching for "She Wolf" by Shakira...
# Done.
# She Wolf (2009) - 366 žodžių (viso: 88740)
# Searching for "Chantaje" by Shakira...
# Done.
# Chantaje (2016) - 500 žodžių (viso: 89240)
# Surandame dainas atlikejui: Lady Gaga
# Searching for songs by Lady Gaga...
#
# Song 1: "Shallow"
# Song 2: "Die With A Smile"
# Song 3: "Poker Face"
# Song 4: "Bad Romance"
# Song 5: "Abracadabra"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Shallow" by Lady Gaga...
# Done.
# Shallow (2018) - 270 žodžių (viso: 89510)
# Searching for "Die With A Smile" by Lady Gaga...
# Done.
# Searching for "Poker Face" by Lady Gaga...
# Done.
# Poker Face (2008) - 510 žodžių (viso: 90020)
# Searching for "Bad Romance" by Lady Gaga...
# Done.
# Bad Romance (2009) - 617 žodžių (viso: 90637)
# Searching for "Abracadabra" by Lady Gaga...
# Done.
# Surandame dainas atlikejui: Imagine Dragons
# Searching for songs by Imagine Dragons...
#
# Song 1: "Believer"
# Song 2: "Thunder"
# Song 3: "Demons"
# Song 4: "Enemy"
# Song 5: "Radioactive"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Believer" by Imagine Dragons...
# Done.
# Believer (2017) - 456 žodžių (viso: 91093)
# Searching for "Thunder" by Imagine Dragons...
# Done.
# Thunder (2017) - 312 žodžių (viso: 91405)
# Searching for "Demons" by Imagine Dragons...
# Done.
# Demons (2013) - 355 žodžių (viso: 91760)
# Searching for "Enemy" by Imagine Dragons...
# Done.
# Searching for "Radioactive" by Imagine Dragons...
# Done.
# Radioactive (2012) - 281 žodžių (viso: 92041)
# Surandame dainas atlikejui: The Weeknd
# Searching for songs by The Weeknd...
#
# Song 1: "The Hills"
# Song 2: "Starboy"
# Song 3: "Die For You"
# Song 4: "Can’t Feel My Face"
# Song 5: "Reminder"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "The Hills" by The Weeknd...
# Done.
# The Hills (2015) - 502 žodžių (viso: 92543)
# Searching for "Starboy" by The Weeknd...
# Done.
# Starboy (2016) - 533 žodžių (viso: 93076)
# Searching for "Die For You" by The Weeknd...
# Done.
# Die For You (2016) - 490 žodžių (viso: 93566)
# Searching for "Can’t Feel My Face" by The Weeknd...
# Done.
# Can’t Feel My Face (2015) - 552 žodžių (viso: 94118)
# Searching for "Reminder" by The Weeknd...
# Done.
# Reminder (2016) - 563 žodžių (viso: 94681)
# Surandame dainas atlikejui: Kendrick Lamar
# Searching for songs by Kendrick Lamar...
#
# Song 1: "Not Like Us"
# Song 2: "HUMBLE."
# Song 3: "euphoria"
# Song 4: "m.A.A.d city"
# Song 5: "Swimming Pools (Drank)"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Not Like Us" by Kendrick Lamar...
# Done.
# Searching for "HUMBLE." by Kendrick Lamar...
# Done.
# HUMBLE. (2017) - 643 žodžių (viso: 95324)
# Searching for "euphoria" by Kendrick Lamar...
# Done.
# Searching for "m.A.A.d city" by Kendrick Lamar...
# Done.
# m.A.A.d city (2012) - 1177 žodžių (viso: 96501)
# Searching for "Swimming Pools (Drank)" by Kendrick Lamar...
# Done.
# Swimming Pools (Drank) (2012) - 914 žodžių (viso: 97415)
# Surandame dainas atlikejui: David Guetta
# Searching for songs by David Guetta...
#
# Song 1: "Titanium"
# Song 2: "2U"
# Song 3: "Hey Mama"
# Song 4: "Say My Name"
# Song 5: "I’m Good (Blue)"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Titanium" by David Guetta...
# Done.
# Titanium (2011) - 266 žodžių (viso: 97681)
# Searching for "2U" by David Guetta...
# Done.
# 2U (2017) - 328 žodžių (viso: 98009)
# Searching for "Hey Mama" by David Guetta...
# Done.
# Hey Mama (2015) - 620 žodžių (viso: 98629)
# Searching for "Say My Name" by David Guetta...
# Done.
# Say My Name (2018) - 528 žodžių (viso: 99157)
# Searching for "I’m Good (Blue)" by David Guetta...
# Done.
# Surandame dainas atlikejui: Calvin Harris
# Searching for songs by Calvin Harris...
#
# Song 1: "Slide"
# Song 2: "Feels"
# Song 3: "How Deep Is Your Love"
# Song 4: "One Kiss"
# Song 5: "Promises"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "Slide" by Calvin Harris...
# Done.
# Slide (2017) - 594 žodžių (viso: 99751)
# Searching for "Feels" by Calvin Harris...
# Done.
# Feels (2017) - 536 žodžių (viso: 100287)
# Searching for "How Deep Is Your Love" by Calvin Harris...
# Done.
# How Deep Is Your Love (2015) - 449 žodžių (viso: 100736)
# Searching for "One Kiss" by Calvin Harris...
# Done.
# One Kiss (2018) - 361 žodžių (viso: 101097)
# Searching for "Promises" by Calvin Harris...
# Done.
# Promises (2018) - 392 žodžių (viso: 101489)
# Iš viso surinkta 220 dainų, 101489 žodžių

# %% [markdown]
# # Papildymas

# %%
GENIUS_API_TOKEN = "(Čia turėtų būti API raktas)"
BASE_URL = "https://api.genius.com"
filename = "Dainu_analize_1980_2020.json"

start_year = 1980
end_year = 2020

artists_in_period = ["Run–DMC", "Mariah Carey"]

genius = lyricsgenius.Genius(
    GENIUS_API_TOKEN,
    skip_non_songs=True,
    excluded_terms=["(Remix)", "(Live)"],
    timeout = 15,
    retries = 3
)

def get_song_release_date(song_id):
    headers = {"Authorization": f"Bearer {GENIUS_API_TOKEN}"}
    response = requests.get(f"{BASE_URL}/songs/{song_id}", headers=headers)

    if response.status_code == 200:
        song_data = response.json()["response"]["song"]
        return song_data.get("release_date", None)
    else:
        print(f"Klaida gaunant release_date song_id {song_id}: {response.status_code}")
        return None
    
if os.path.exists(filename):
    with open(filename, "r", encoding = "utf-8",) as f:
        all_lyrics = json.load(f)
    existing_titles = {(s["artist"], s["title"]) for s in all_lyrics}
    print(f"Yra jau {len(all_lyrics)} dainų faile")
else:
    all_lyrics = []
    existing_titles = set()

total_word_count = sum(song["word_count"] for song in all_lyrics)

for artist_name in artists_in_period:
    print(f"Surandame dainas atlikejui: {artist_name}")
    try:
        artist = genius.search_artist(artist_name, max_songs=5, sort="popularity")
    except Exception as e:
        print(f"Klaida su atlikeju {artist_name}: {e}")
        continue

    time.sleep(2)

    if artist:
        for song in artist.songs:
            if (artist.name, song.title) in existing_titles:
                print(f"Praleidžiama (jau yra): {song.title}")
                continue
            full_song = genius.search_song(song.title, artist.name)
            if not full_song or not full_song.lyrics:
                print(f"Nepavyko gauti lyrics dainai: {song.title}")
                continue
            
            release_date = get_song_release_date(full_song.id)

            if release_date:
                try:
                    release_year = datetime.strptime(release_date, "%Y-%m-%d").year
                except ValueError:
                    try:
                        release_year = datetime.strptime(release_date, "%Y").year
                    except ValueError:
                        print(f"Klaida: neteisingas release_date formatas {release_date} dainai {song.title}")
                        release_year = None
            else:
                release_year = None

            if release_year is None or (start_year <= release_year <= end_year):
                lyrics = full_song.lyrics
                word_count = len(lyrics.split())
                total_word_count += word_count
                all_lyrics.append({
                    "artist": full_song.artist,
                    "title": full_song.title,
                    "year": release_year,
                    "lyrics": lyrics,
                    "word_count": word_count
                })
                existing_titles.add((artist.name, song.title))
                print(f"{full_song.title} ({release_year}) - {word_count} žodžių (viso: {total_word_count})")

all_lyrics.sort(key=lambda song: song["year"] if song["year"] is not None else 0)

with open(filename, "w", encoding = "utf-8") as f:
    json.dump(all_lyrics, f, ensure_ascii = False, indent = 2)

print(f"Iš viso surinkta {len(all_lyrics)} dainų, {total_word_count} žodžių")
# Out:
# Yra jau 398 dainų faile
# Surandame dainas atlikejui: Run–DMC
# Searching for songs by Run–DMC...
#
# Song 1: "It’s Tricky"
# Song 2: "Walk This Way"
# Song 3: "Christmas in Hollis"
# Song 4: "Peter Piper"
# Song 5: "It’s Like That"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "It’s Tricky" by Run–DMC...
# Done.
# It’s Tricky (1987) - 521 žodžių (viso: 173460)
# Searching for "Walk This Way" by Run–DMC...
# Done.
# Walk This Way (1986) - 455 žodžių (viso: 173915)
# Searching for "Christmas in Hollis" by Run–DMC...
# Done.
# Christmas in Hollis (1987) - 379 žodžių (viso: 174294)
# Searching for "Peter Piper" by Run–DMC...
# Done.
# Peter Piper (1986) - 464 žodžių (viso: 174758)
# Searching for "It’s Like That" by Run–DMC...
# Done.
# It’s Like That (1983) - 659 žodžių (viso: 175417)
# Surandame dainas atlikejui: Mariah Carey
# Searching for songs by Mariah Carey...
#
# Song 1: "All I Want for Christmas Is You"
# Song 2: "We Belong Together"
# Song 3: "Obsessed"
# Song 4: "Fantasy"
# Song 5: "#Beautiful"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
# Searching for "All I Want for Christmas Is You" by Mariah Carey...
# Done.
# All I Want for Christmas Is You (1994) - 450 žodžių (viso: 175867)
# Searching for "We Belong Together" by Mariah Carey...
# Done.
# We Belong Together (2005) - 542 žodžių (viso: 176409)
# Searching for "Obsessed" by Mariah Carey...
# Done.
# Obsessed (2009) - 656 žodžių (viso: 177065)
# Searching for "Fantasy" by Mariah Carey...
# Done.
# Fantasy (1995) - 354 žodžių (viso: 177419)
# Searching for "#Beautiful" by Mariah Carey...
# Done.
# #Beautiful (2013) - 329 žodžių (viso: 177748)
# Iš viso surinkta 408 dainų, 177748 žodžių
